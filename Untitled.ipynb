# %% [markdown]
# ## Heroes Core

# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %%
df_powers = pd.read_csv('data/superhero_powers_superhero_powers.csv')
df_powers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
df_sp_info = pd.read_csv('data/superhero_info_superhero_info.csv')
df_sp_info.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %% [markdown]
# ## I. Clean the files and combine them into one final DataFrame.
#
# This dataframe should have the following columns:
# - Hero (Just the name of the Hero)
# - Publisher
# - Gender
# - Eye color
# - Race
# - Hair color
# - Height (numeric)
# - Skin color
# - Alignment
# - Weight (numeric)
# - Plus, one-hot-encoded columns for every power that appears in the dataset. E.g.:
# - Agility
# - Flight
# - Superspeed
# - etc.

# %%
df_sp_info[['Hero','Publisher']]=df_sp_info['Hero|Publisher'].str.split('|',expand=True)

# %%
df_sp_info.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
df_sp_info.drop(columns=['Hero|Publisher'], inplace = True)

# %%
df_sp_info
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color                                  Measurements             Hero  \
# ...

# %%
df_sp_info['Measurements'] = df_sp_info['Measurements'].str.replace("'",'"')
# apply the json.loads on full column
df_sp_info['Measurements'] = df_sp_info['Measurements'].apply(json.loads)
df_sp_info['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
h_w = df_sp_info['Measurements'].apply(pd.Series)
h_w
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
h_w['Height'] = h_w['Height'].str.replace(" cm","")
h_w['Height']
# Out:
# 0      203.0
# 1      191.0
# 2      185.0
# 3      203.0
# 4      193.0
#        ...
# 458    183.0
# 459    165.0
# 460     66.0
# 461    170.0
# 462    185.0
# Name: Height, Length: 463, dtype: object

# %%
h_w['Weight'] = h_w['Weight'].str.replace(" kg","")
h_w.head()
# Out:
#   Height Weight
# 0  203.0  441.0
# 1  191.0   65.0
# 2  185.0   90.0
# 3  203.0  441.0
# 4  193.0  122.0

# %%
df_sp_info = pd.concat((df_sp_info, h_w), axis = 1)
df_sp_info.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher Height Weight
# 0      Marvel Comics  203.0  441.0
# 1  Dark Horse Comics  191.0   65.0

# %%
df_sp_info.drop(columns = ['Measurements'], inplace = True)

# %%
df_sp_info
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher Height Weight
# 0      Unknown           A-Bomb      Marvel Comics  203.0  441.0
# ...

# %%
df_powers.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
df_powers['Powers'].value_counts()
# Out:
# Intelligence                                                                                                                                                                                                                                                         8
# Durability,Super Strength                                                                                                                                                                                                                                            5
# Agility,Stealth,Marksmanship,Weapons Master,Stamina                                                                                                                                                                                                                  4
# ...

# %%
df_powers['Powers_Split_1']=df_powers['Powers'].str.split(',', expand = False)

# %%
df_powers.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                       Powers_Split_1
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
exploded = df_powers.explode('Powers_Split_1')
exploded.head()
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#         Powers_Split_1
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
cols_to_make = exploded['Powers_Split_1'].dropna().unique()

# %%
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
for col in cols_to_make:
  df_powers[col] = df_powers['Powers'].str.contains(col)
# Out:
# C:\Users\mkwak\AppData\Local\Temp\ipykernel_15004\3536730005.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_powers[col] = df_powers['Powers'].str.contains(col)
# C:\Users\mkwak\AppData\Local\Temp\ipykernel_15004\3536730005.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_powers[col] = df_powers['Powers'].str.contains(col)
# ...

# %%
df_powers.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                       Powers_Split_1  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# 2  [Agility, Accelerated Healing, Cold Resistance...     True            True
# 3                               [Lantern Power Ring]    False           False
# 4  [Accelerated Healing, Intelligence, Super Stre...    False            True
#
#    Stamina  Super Speed  Accelerated Healing  Durability  Longevity  ...  \
# ...

# %%
df_sp_info
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher Height Weight
# 0      Unknown           A-Bomb      Marvel Comics  203.0  441.0
# ...

# %%
final_df = pd.merge(df_sp_info, df_powers, left_on = 'Hero', right_on = 'hero_names')
final_df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics  203.0  441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0  ...           False
# 2       Abin Sur          DC Comics  185.0   90.0  ...           False
# 3    Abomination      Marvel Comics  203.0  441.0  ...           False
# 4  Absorbing Man      Marvel Comics  193.0  122.0  ...           False
#
#   Omnipresent Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %%
final_df
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher Height Weight  ...  \
# ...

# %%
final_df = final_df.astype({'Height': 'float', 'Weight': 'float'})

# %%
super_speed = final_df['Super Speed'] == True
final_df[super_speed].describe()
# Out:
#            Height      Weight
# count  198.000000  198.000000
# mean   189.444444  129.404040
# std     56.186730  122.625087
# min     64.000000   14.000000
# 25%    178.000000   69.250000
# 50%    183.000000   90.000000
# 75%    193.000000  135.000000
# max    876.000000  855.000000

# %%
final_df[~super_speed].describe()
# Out:
#            Height      Weight
# count  265.000000  265.000000
# mean   186.376226  101.773585
# std     63.402018   91.745168
# min     15.200000    4.000000
# 25%    170.000000   59.000000
# 50%    183.000000   79.000000
# 75%    188.000000   97.000000
# max    975.000000  900.000000

# %%
##- The average weight of a super speed hero is 129.404. The average weight without super speed is 101.77

# %%
final_df.groupby(['Publisher']).describe()
# Out:
#                   Height                                                       \
#                    count        mean        std    min     25%    50%     75%
# Publisher
# DC Comics          138.0  181.923913  23.991856   62.5  173.00  183.0  188.00
# Dark Horse Comics   11.0  176.909091  54.459994   71.0  147.00  183.0  207.00
# George Lucas         5.0  159.600000  53.388201   66.0  168.00  183.0  183.00
# Image Comics         1.0  211.000000        NaN  211.0  211.00  211.0  211.00
# Marvel Comics      297.0  191.546128  72.316521   15.2  175.00  183.0  191.00
# Shueisha             4.0  171.500000   4.041452  168.0  168.00  171.5  175.00
# Star Trek            2.0  181.500000   4.949747  178.0  179.75  181.5  183.25
# Team Epic TV         4.0  180.750000   4.349329  175.0  178.75  181.5  183.50
# Unknown              1.0  178.000000        NaN  178.0  178.00  178.0  178.00
#
#                          Weight                                                \
# ...
